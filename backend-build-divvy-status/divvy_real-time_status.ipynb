# %%
##################################################################################################
##################################################################################################


### This file and the source code provided can be used only for the projects and assignments  
### of this course

### Last Edit by Dr. Atef Bader: 3/17/2021


##################################################################################################
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\nikhil\appdata\local\programs\python\python39\lib\site-packages (2.9.1)

# %% [markdown]
# ## Divvy
#
# **Divvy** is a bicycle sharing system in the City of Chicago.
#
# Click __[here](https://en.wikipedia.org/wiki/Divvy)__ to read more about **Divvy**
#
#
# Click __[here](https://www.divvybikes.com/)__ to visit the official website for **Divvy**

# %% [markdown]
# This script will send a heartbeat every 2 minutes to divvy to collect their stations status in the City of Chicago.

# %% [markdown]
# ### PostgreSQL
#
# We will collect the data from **Divvy** servers and store the data in a table on **PostgreSQL** server.
#
# This python script will send a heartbeat to Divvy every 2 minutes to retrieve the  status of the Divvy dock stations and store the data on PostgreSQL server.
#
# You need the package **psycopg2** to Connect to **PostgreSQL** server.
#
# Execute the **pip install** command from the command window to install  the package listed bove:
# - pip install psycopg2

# %%
import json
import requests
import datetime
import time
import os
import psycopg2
import pandas as pd
from urllib.request import urlopen
import json
import csv
from pprint import pprint
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT 
from datetime import datetime

# %%
from elasticsearch import Elasticsearch, helpers 

es = Elasticsearch()

# %%
def set_data(input_file, index_name = "divvy_station_logs", doc_type_name="log"):
    for line in input_file:
        
        yield {
            "_index": index_name,
            "_type": doc_type_name,
            "_source": line
            
        }

# %%
def load(es, input_file, **kwargs):
    success, _ = helpers.bulk(es, set_data(input_file, **kwargs))

# %%
# Get divvy statations status
# Status is returned as a json reply

# response = urlopen('https://feeds.divvybikes.com/stations/stations.json')

response_stations_info = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_information.json')

response = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_status.json')

# Extract the body of the reply
response_body = response.read()
response_stations_info = response_stations_info.read()

# Decode the format in json format
stations_json = json.loads(response_body.decode("utf-8"))
stations_info_json = json.loads(response_stations_info.decode("utf-8"))

# %%
pprint(stations_json)
# Out:
# {'data': {'stations': [{'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200648,
#                         'legacy_id': '2',
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 30,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '2',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637192452,
#                         'legacy_id': '3',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 52,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'station_id': '3',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637195180,
#                         'legacy_id': '4',
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '4',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200138,
#                         'legacy_id': '5',
#                         'num_bikes_available': 18,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 8,
#                         'station_id': '5',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201270,
#                         'legacy_id': '6',
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 32,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'station_id': '6',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200642,
#                         'legacy_id': '7',
#                         'num_bikes_available': 19,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 5,
#                         'station_id': '7',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637177793,
#                         'legacy_id': '9',
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'station_id': '9',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637184117,
#                         'legacy_id': '11',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '11',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637174504,
#                         'legacy_id': '12',
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '12',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200694,
#                         'legacy_id': '13',
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 21,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'station_id': '13',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201490,
#                         'legacy_id': '14',
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'station_id': '14',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637197753,
#                         'legacy_id': '15',
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '15',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201614,
#                         'legacy_id': '16',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '16',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201165,
#                         'legacy_id': '17',
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 5,
#                         'station_id': '17',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637199062,
#                         'legacy_id': '18',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '18',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637199174,
#                         'legacy_id': '19',
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '19',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200123,
#                         'legacy_id': '20',
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 8,
#                         'station_id': '20',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637199561,
#                         'legacy_id': '21',
#                         'num_bikes_available': 18,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 8,
#                         'station_id': '21',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637199236,
#                         'legacy_id': '22',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '22',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637194962,
#                         'legacy_id': '23',
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'station_id': '23',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201171,
#                         'legacy_id': '24',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '24',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200490,
#                         'legacy_id': '25',
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '25',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200026,
#                         'legacy_id': '26',
#                         'num_bikes_available': 30,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 0,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 9,
#                         'station_id': '26',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201255,
#                         'legacy_id': '27',
#                         'num_bikes_available': 17,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'station_id': '27',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637198979,
#                         'legacy_id': '28',
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'station_id': '28',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637198994,
#                         'legacy_id': '29',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '29',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201295,
#                         'legacy_id': '30',
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 6,
#                         'station_id': '30',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200881,
#                         'legacy_id': '31',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 18,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'station_id': '31',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201448,
#                         'legacy_id': '32',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 15,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'station_id': '32',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201314,
#                         'legacy_id': '33',
#                         'num_bikes_available': 13,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'station_id': '33',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637165873,
#                         'legacy_id': '34',
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '34',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200502,
#                         'legacy_id': '35',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 44,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '35',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201422,
#                         'legacy_id': '36',
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 23,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'station_id': '36',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200857,
#                         'legacy_id': '37',
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '37',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200620,
#                         'legacy_id': '38',
#                         'num_bikes_available': 19,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'station_id': '38',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637198413,
#                         'legacy_id': '39',
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 9,
#                         'station_id': '39',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201508,
#                         'legacy_id': '40',
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 7,
#                         'station_id': '40',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201065,
#                         'legacy_id': '41',
#                         'num_bikes_available': 10,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'station_id': '41',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637185698,
#                         'legacy_id': '42',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '42',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637199260,
#                         'legacy_id': '43',
#                         'num_bikes_available': 32,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '43',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201324,
#                         'legacy_id': '44',
#                         'num_bikes_available': 11,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 12,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'station_id': '44',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200505,
#                         'legacy_id': '45',
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '45',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637199633,
#                         'legacy_id': '46',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '46',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201590,
#                         'legacy_id': '47',
#                         'num_bikes_available': 7,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 24,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '47',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201557,
#                         'legacy_id': '48',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 42,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '48',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637198786,
#                         'legacy_id': '49',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 34,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '49',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200369,
#                         'legacy_id': '50',
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 23,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '50',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637195871,
#                         'legacy_id': '51',
#                         'num_bikes_available': 20,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 23,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 8,
#                         'station_id': '51',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200268,
#                         'legacy_id': '52',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 30,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'station_id': '52',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201599,
#                         'legacy_id': '53',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 2,
#                         'num_docks_available': 22,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '53',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637199732,
#                         'legacy_id': '54',
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'station_id': '54',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637197800,
#                         'legacy_id': '55',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 17,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '55',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201407,
#                         'legacy_id': '56',
#                         'num_bikes_available': 16,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 13,
#                         'station_id': '56',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637197750,
#                         'legacy_id': '57',
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '57',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200917,
#                         'legacy_id': '58',
#                         'num_bikes_available': 12,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 11,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 9,
#                         'station_id': '58',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200284,
#                         'legacy_id': '59',
#                         'num_bikes_available': 16,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 5,
#                         'station_id': '59',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200906,
#                         'legacy_id': '60',
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '60',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637199878,
#                         'legacy_id': '61',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '61',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637196066,
#                         'legacy_id': '62',
#                         'num_bikes_available': 19,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'station_id': '62',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201038,
#                         'legacy_id': '66',
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 17,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'station_id': '66',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201533,
#                         'legacy_id': '67',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 23,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '67',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637191979,
#                         'legacy_id': '68',
#                         'num_bikes_available': 16,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 9,
#                         'station_id': '68',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201012,
#                         'legacy_id': '69',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 18,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '69',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200743,
#                         'legacy_id': '71',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 20,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '71',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637200893,
#                         'legacy_id': '72',
#                         'num_bikes_available': 33,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 7,
#                         'station_id': '72',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637199707,
#                         'legacy_id': '73',
#                         'num_bikes_available': 14,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'station_id': '73',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201460,
#                         'legacy_id': '74',
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 14,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'station_id': '74',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637197692,
#                         'legacy_id': '75',
#                         'num_bikes_available': 18,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 25,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'station_id': '75',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637193022,
#                         'legacy_id': '76',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 38,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '76',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201240,
#                         'legacy_id': '77',
#                         'num_bikes_available': 21,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 11,
#                         'station_id': '77',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637199640,
#                         'legacy_id': '80',
#                         'num_bikes_available': 17,
#                         'num_bikes_disabled': 1,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'station_id': '80',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201246,
#                         'legacy_id': '81',
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 6,
#                         'station_id': '81',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201603,
#                         'legacy_id': '84',
#                         'num_bikes_available': 6,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 13,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'station_id': '84',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637199565,
#                         'legacy_id': '85',
#                         'num_bikes_available': 15,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'station_id': '85',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201020,
#                         'legacy_id': '86',
#                         'num_bikes_available': 9,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'station_id': '86',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1637201582,
#                         'legacy_id': '87',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 16,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '87',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
# ...
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573280,
#                         'legacy_id': '1575949498093662918',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'station_id': '1575949498093662918',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573290,
#                         'legacy_id': '1575949515273532128',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '1575949515273532128',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573288,
#                         'legacy_id': '1582242323927553626',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1582242323927553626',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573270,
#                         'legacy_id': '1594041777104953202',
#                         'num_bikes_available': 4,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 4,
#                         'station_id': '1594041777104953202',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573289,
#                         'legacy_id': '1436495109493626544',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1436495109493626544',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573273,
#                         'legacy_id': '1561012874421056046',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'station_id': '1561012874421056046',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573274,
#                         'legacy_id': '1436495115557663136',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1436495115557663136',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573281,
#                         'legacy_id': '1561012883010990646',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1561012883010990646',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573280,
#                         'legacy_id': '1582242280977880604',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1582242280977880604',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573290,
#                         'legacy_id': '1448642179437434482',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 10,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1448642179437434482',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573283,
#                         'legacy_id': '1575949506683597522',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1575949506683597522',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573273,
#                         'legacy_id': '1448642188027369090',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 6,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1448642188027369090',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573289,
#                         'legacy_id': '1436495105198659242',
#                         'num_bikes_available': 3,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 5,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 3,
#                         'station_id': '1436495105198659242',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573287,
#                         'legacy_id': '1561012895895892548',
#                         'num_bikes_available': 5,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 4,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 5,
#                         'station_id': '1561012895895892548',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573280,
#                         'legacy_id': '1448642183732401788',
#                         'num_bikes_available': 8,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 2,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 8,
#                         'station_id': '1448642183732401788',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636653049,
#                         'legacy_id': '1594046422462976738',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1594046422462976738',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573279,
#                         'legacy_id': '1594041781399920504',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1594041781399920504',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573274,
#                         'legacy_id': '1561012887305957952',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1561012887305957952',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573271,
#                         'legacy_id': '1563698722681128992',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1563698722681128992',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573277,
#                         'legacy_id': '1594046400988140226',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1594046400988140226',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 0,
#                         'is_renting': 0,
#                         'is_returning': 0,
#                         'last_reported': 1637178464,
#                         'legacy_id': '1594046465420805300',
#                         'num_bikes_available': 0,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 9,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 0,
#                         'station_id': '1594046465420805300',
#                         'station_status': 'planned'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573278,
#                         'legacy_id': '1594046461117682452',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 7,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'station_id': '1594046461117682452',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573269,
#                         'legacy_id': '1575949493798695616',
#                         'num_bikes_available': 1,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 8,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 1,
#                         'station_id': '1575949493798695616',
#                         'station_status': 'active'},
#                        {'eightd_has_available_keys': False,
#                         'is_installed': 1,
#                         'is_renting': 1,
#                         'is_returning': 1,
#                         'last_reported': 1636573285,
#                         'legacy_id': '1448642162257565290',
#                         'num_bikes_available': 2,
#                         'num_bikes_disabled': 0,
#                         'num_docks_available': 1,
#                         'num_docks_disabled': 0,
#                         'num_ebikes_available': 2,
#                         'station_id': '1448642162257565290',
#                         'station_status': 'active'}]},
#  'last_updated': 1637201615,
#  'ttl': 5}

# %%
pprint(stations_info_json)
# Out:
# {'data': {'stations': [{'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a36d9e-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8765351944122,
#                         'legacy_id': '2',
#                         'lon': -87.62047290802002,
#                         'name': 'Buckingham Fountain',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15541',
#                         'station_id': '2',
#                         'station_type': 'classic'},
#                        {'capacity': 55,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a37378-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.86722595682,
#                         'legacy_id': '3',
#                         'lon': -87.6153553902,
#                         'name': 'Shedd Aquarium',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15544',
#                         'station_id': '3',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a378ca-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.856268,
#                         'legacy_id': '4',
#                         'lon': -87.613348,
#                         'name': 'Burnham Harbor',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15545',
#                         'station_id': '4',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a37e26-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.874053,
#                         'legacy_id': '5',
#                         'lon': -87.627716,
#                         'name': 'State St & Harrison St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'SL-007',
#                         'station_id': '5',
#                         'station_type': 'classic'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a38363-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.886976,
#                         'legacy_id': '6',
#                         'lon': -87.612813,
#                         'name': 'Dusable Harbor',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000064',
#                         'station_id': '6',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3888b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.88634906269,
#                         'legacy_id': '7',
#                         'lon': -87.6175165471,
#                         'name': 'Field Blvd & South Water St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '15534',
#                         'station_id': '7',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a39301-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.82879201994,
#                         'legacy_id': '9',
#                         'lon': -87.6806044594,
#                         'name': 'Leavitt St & Archer Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000068',
#                         'station_id': '9',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3983e-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.76663823695,
#                         'legacy_id': '11',
#                         'lon': -87.5764501141,
#                         'name': 'Jeffery Blvd & 71st St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000018',
#                         'station_id': '11',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a39d55-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.7664094567,
#                         'legacy_id': '12',
#                         'lon': -87.5656875719,
#                         'name': 'South Shore Dr & 71st St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000002',
#                         'station_id': '12',
#                         'station_type': 'classic'},
#                        {'capacity': 35,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3a282-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.932418,
#                         'legacy_id': '13',
#                         'lon': -87.652705,
#                         'name': 'Wilton Ave & Diversey Pkwy',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000014',
#                         'station_id': '13',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3a7b4-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.858086,
#                         'legacy_id': '14',
#                         'lon': -87.651073,
#                         'name': 'Morgan St & 18th St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13163',
#                         'station_id': '14',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3ace6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.858166,
#                         'legacy_id': '15',
#                         'lon': -87.656495,
#                         'name': 'Racine Ave & 18th St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13164',
#                         'station_id': '15',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3b202-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.90985465216731,
#                         'legacy_id': '16',
#                         'lon': -87.66993016004562,
#                         'name': 'Paulina Ave & North Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000037',
#                         'station_id': '16',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3b731-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.903119,
#                         'legacy_id': '17',
#                         'lon': -87.673935,
#                         'name': 'Honore St & Division St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000034',
#                         'station_id': '17',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3bc53-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.88314336439022,
#                         'legacy_id': '18',
#                         'lon': -87.63724207878113,
#                         'name': 'Wacker Dr & Washington St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000072',
#                         'station_id': '18',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3c174-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.868968,
#                         'legacy_id': '19',
#                         'lon': -87.659141,
#                         'name': 'Throop St & Taylor St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13139',
#                         'station_id': '19',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3c696-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.910522,
#                         'legacy_id': '20',
#                         'lon': -87.653106,
#                         'name': 'Sheffield Ave & Kingsbury St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13154',
#                         'station_id': '20',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3cbac-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87772613,
#                         'legacy_id': '21',
#                         'lon': -87.65478743,
#                         'name': 'Aberdeen St & Jackson Blvd',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13157',
#                         'station_id': '21',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3d1b8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8694821,
#                         'legacy_id': '22',
#                         'lon': -87.6554864,
#                         'name': 'May St & Taylor St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13160',
#                         'station_id': '22',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3d6f0-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.902924,
#                         'legacy_id': '23',
#                         'lon': -87.637715,
#                         'name': 'Orleans St & Elm St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000006',
#                         'station_id': '23',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3dc37-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89184737210993,
#                         'legacy_id': '24',
#                         'lon': -87.62058019638062,
#                         'name': 'Fairbanks Ct & Grand Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000003',
#                         'station_id': '24',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3e158-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89766,
#                         'legacy_id': '25',
#                         'lon': -87.62351,
#                         'name': 'Michigan Ave & Pearson St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13034',
#                         'station_id': '25',
#                         'station_type': 'classic'},
#                        {'capacity': 31,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3e67b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.890847040623804,
#                         'legacy_id': '26',
#                         'lon': -87.61861681938171,
#                         'name': 'New St & Illinois St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000013',
#                         'station_id': '26',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3eb9a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.91021,
#                         'legacy_id': '27',
#                         'lon': -87.6435,
#                         'name': 'Larrabee St & North Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000008',
#                         'station_id': '27',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3f0c6-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.91468,
#                         'legacy_id': '28',
#                         'lon': -87.64332,
#                         'name': 'Larrabee St & Menomonee St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000007',
#                         'station_id': '28',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3f5e9-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.90068,
#                         'legacy_id': '29',
#                         'lon': -87.6626,
#                         'name': 'Noble St & Milwaukee Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13290',
#                         'station_id': '29',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a3fb5d-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.899643,
#                         'legacy_id': '30',
#                         'lon': -87.6677,
#                         'name': 'Ashland Ave & Augusta Blvd',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13248',
#                         'station_id': '30',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a40088-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.896746973093805,
#                         'legacy_id': '31',
#                         'lon': -87.63566762208939,
#                         'name': 'Franklin St & Chicago Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13017',
#                         'station_id': '31',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a405a1-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87464,
#                         'legacy_id': '32',
#                         'lon': -87.65703,
#                         'name': 'Racine Ave & Congress Pkwy',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000025',
#                         'station_id': '32',
#                         'station_type': 'classic'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a40ad8-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.877181,
#                         'legacy_id': '33',
#                         'lon': -87.627844,
#                         'name': 'State St & Van Buren St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000035',
#                         'station_id': '33',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a41004-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.9267559875,
#                         'legacy_id': '34',
#                         'lon': -87.6344287848,
#                         'name': 'Cannon Dr & Fullerton Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13124',
#                         'station_id': '34',
#                         'station_type': 'classic'},
#                        {'capacity': 47,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a41526-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.892278,
#                         'legacy_id': '35',
#                         'lon': -87.612043,
#                         'name': 'Streeter Dr & Grand Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13022',
#                         'station_id': '35',
#                         'station_type': 'classic'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a41af5-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8777079559,
#                         'legacy_id': '36',
#                         'lon': -87.6353211408,
#                         'name': 'Franklin St & Jackson Blvd',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000025',
#                         'station_id': '36',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4203a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8793563587,
#                         'legacy_id': '37',
#                         'lon': -87.6297910363,
#                         'name': 'Dearborn St & Adams St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000005',
#                         'station_id': '37',
#                         'station_type': 'classic'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a42574-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.88602082773,
#                         'legacy_id': '38',
#                         'lon': -87.6308760584,
#                         'name': 'Clark St & Lake St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000012',
#                         'station_id': '38',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a42a93-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87947235235,
#                         'legacy_id': '39',
#                         'lon': -87.6256886059,
#                         'name': 'Wabash Ave & Adams St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000015',
#                         'station_id': '39',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a42fa7-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87934437346,
#                         'legacy_id': '40',
#                         'lon': -87.6319852213,
#                         'name': 'LaSalle St & Adams St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'KA1503000034',
#                         'station_id': '40',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a434ce-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.87207763285,
#                         'legacy_id': '41',
#                         'lon': -87.6295437729,
#                         'name': 'Federal St & Polk St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'SL-008',
#                         'station_id': '41',
#                         'station_type': 'classic'},
#                        {'capacity': 11,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a43a25-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.852619,
#                         'legacy_id': '42',
#                         'lon': -87.626488,
#                         'name': 'Wabash Ave & Cermak Rd',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000001',
#                         'station_id': '42',
#                         'station_type': 'classic'},
#                        {'capacity': 43,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a43f48-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8839840647265,
#                         'legacy_id': '43',
#                         'lon': -87.6246839761734,
#                         'name': 'Michigan Ave & Washington St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13001',
#                         'station_id': '43',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a44476-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.88462107257936,
#                         'legacy_id': '44',
#                         'lon': -87.62783423066139,
#                         'name': 'State St & Randolph St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000029',
#                         'station_id': '44',
#                         'station_type': 'classic'},
#                        {'capacity': 15,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4499f-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.876243,
#                         'legacy_id': '45',
#                         'lon': -87.624426,
#                         'name': 'Michigan Ave & Ida B Wells Dr',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000010',
#                         'station_id': '45',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a44ec7-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.89993001,
#                         'legacy_id': '46',
#                         'lon': -87.63443007,
#                         'name': 'Wells St & Walton St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000011',
#                         'station_id': '46',
#                         'station_type': 'classic'},
#                        {'capacity': 31,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a453fa-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.889187,
#                         'legacy_id': '47',
#                         'lon': -87.627754,
#                         'name': 'State St & Kinzie St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': '13050',
#                         'station_id': '47',
#                         'station_type': 'classic'},
#                        {'capacity': 43,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4591a-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.897764,
#                         'legacy_id': '48',
#                         'lon': -87.642884,
#                         'name': 'Larrabee St & Kingsbury St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000009',
#                         'station_id': '48',
#                         'station_type': 'classic'},
#                        {'capacity': 39,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a45e3b-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.881319815,
#                         'legacy_id': '49',
#                         'lon': -87.6295209193,
#                         'name': 'Dearborn St & Monroe St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000006',
#                         'station_id': '49',
#                         'station_type': 'classic'},
#                        {'capacity': 35,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a46361-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.8759326655,
#                         'legacy_id': '50',
#                         'lon': -87.6305845355,
#                         'name': 'Clark St & Ida B Wells Dr',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000009',
#                         'station_id': '50',
#                         'station_type': 'classic'},
#                        {'capacity': 43,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a46896-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.884576228,
#                         'legacy_id': '51',
#                         'lon': -87.63188991,
#                         'name': 'Clark St & Randolph St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000030',
#                         'station_id': '51',
#                         'station_type': 'classic'},
#                        {'capacity': 35,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a46e71-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.886024,
#                         'legacy_id': '52',
#                         'lon': -87.624117,
#                         'name': 'Michigan Ave & Lake St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000011',
#                         'station_id': '52',
#                         'station_type': 'classic'},
#                        {'capacity': 27,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a4739d-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.894722,
#                         'legacy_id': '53',
#                         'lon': -87.634362,
#                         'name': 'Wells St & Huron St',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1306000012',
#                         'station_id': '53',
#                         'station_type': 'classic'},
#                        {'capacity': 19,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'a3a478c9-a135-11e9-9cda-0a87ae2ba916',
#                         'has_kiosk': True,
#                         'lat': 41.896362458,
#                         'legacy_id': '54',
#                         'lon': -87.6540612729,
#                         'name': 'Ogden Ave & Chicago Ave',
#                         'rental_methods': ['TRANSITCARD', 'CREDITCARD', 'KEY'],
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'short_name': 'TA1305000020',
#                         'station_id': '54',
#                         'station_type': 'classic'},
#                        {'capacity': 23,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
# ...
#                         'client_station_id': 'motivate_CHI_1594046439642845942',
#                         'dockless_bikes_parking_zone_capacity': 6,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1594046439642845942',
#                         'has_kiosk': False,
#                         'lat': 41.974712,
#                         'legacy_id': '1594046439642845942',
#                         'lon': -87.697852,
#                         'name': 'California Ave & Winona St',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1594046439642845942',
#                         'station_type': 'lightweight'},
#                        {'address': '3216, North Albany Avenue, Avondale, '
#                                    'Chicago, Jefferson Township, Cook County, '
#                                    'Illinois, 60625, United States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1594046418168009438',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1594046418168009438',
#                         'has_kiosk': False,
#                         'lat': 41.939638,
#                         'legacy_id': '1594046418168009438',
#                         'lon': -87.705263,
#                         'name': 'Albany Ave & Belmont Ave',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1594046418168009438',
#                         'station_type': 'lightweight'},
#                        {'address': 'vehicle storage, North Long Avenue, '
#                                    'Portage Park, Chicago, Jefferson Township, '
#                                    'Cook County, Illinois, 60630, United '
#                                    'States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1571105055115583496',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1571105055115583496',
#                         'has_kiosk': False,
#                         'lat': 41.953038,
#                         'legacy_id': '1571105055115583496',
#                         'lon': -87.7621632,
#                         'name': 'Long & Irving Park',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1571105055115583496',
#                         'station_type': 'lightweight'},
#                        {'address': '6382, West Wrightwood Avenue, Kelvyn '
#                                    'Grove, Beat 2512, Belmont Cragin, Chicago, '
#                                    'Jefferson Township, Cook County, Illinois, '
#                                    '60639, United States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1563698675436490730',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1563698675436490730',
#                         'has_kiosk': False,
#                         'lat': 41.927294,
#                         'legacy_id': '1563698675436490730',
#                         'lon': -87.7852027,
#                         'name': 'Narragansett & Wrightwood',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1563698675436490730',
#                         'station_type': 'lightweight'},
#                        {'address': 'River Park Boat House, 3000, West Argyle '
#                                    'Street, Albany Park, Chicago, Jefferson '
#                                    'Township, Cook County, Illinois, 60625, '
#                                    'United States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1594046439642845944',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1594046439642845944',
#                         'has_kiosk': False,
#                         'lat': 41.972328,
#                         'legacy_id': '1594046439642845944',
#                         'lon': -87.704302,
#                         'name': 'N Shore Channel Trail & Argyle Ave',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1594046439642845944',
#                         'station_type': 'lightweight'},
#                        {'address': '5653-5659, South Kedzie Avenue, Garfield '
#                                    'Manor, Gage Park, Chicago, Lake Township, '
#                                    'Cook County, Illinois, 60629, United '
#                                    'States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1582242323927553620',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1582242323927553620',
#                         'has_kiosk': False,
#                         'lat': 41.789944,
#                         'legacy_id': '1582242323927553620',
#                         'lon': -87.703233,
#                         'name': 'Kedzie Ave & 57th St',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1582242323927553620',
#                         'station_type': 'lightweight'},
#                        {'address': '5255, West Wrightwood Avenue, Kelvyn '
#                                    'Grove, Beat 2521, Belmont Cragin, Chicago, '
#                                    'Jefferson Township, Cook County, Illinois, '
#                                    '60639, United States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1563698696911327228',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1563698696911327228',
#                         'has_kiosk': False,
#                         'lat': 41.9278148,
#                         'legacy_id': '1563698696911327228',
#                         'lon': -87.7583757,
#                         'name': 'Lockwood Ave & Wrightwood Ave',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1563698696911327228',
#                         'station_type': 'lightweight'},
#                        {'address': '5654, North Francisco Avenue, West Ridge, '
#                                    'Chicago, Jefferson Township, Cook County, '
#                                    'Illinois, 60659, United States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1594046456822715150',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1594046456822715150',
#                         'has_kiosk': False,
#                         'lat': 41.984746,
#                         'legacy_id': '1594046456822715150',
#                         'lon': -87.701593,
#                         'name': 'Francisco Ave & Hollywood Ave',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1594046456822715150',
#                         'station_type': 'lightweight'},
#                        {'address': '4400-4420, South Fairfield Avenue, South '
#                                    'Brighton, Brighton Park, Chicago, Lake '
#                                    'Township, Cook County, Illinois, 60632, '
#                                    'United States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1582242293862782512',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1582242293862782512',
#                         'has_kiosk': False,
#                         'lat': 41.813617,
#                         'legacy_id': '1582242293862782512',
#                         'lon': -87.6932272,
#                         'name': 'Fairfield Ave & 44th St',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1582242293862782512',
#                         'station_type': 'lightweight'},
#                        {'address': '3551, North Orange Avenue, Dunning, '
#                                    'Chicago, Jefferson Township, Cook County, '
#                                    'Illinois, 60634, United States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1571105055115583502',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1571105055115583502',
#                         'has_kiosk': False,
#                         'lat': 41.9448846,
#                         'legacy_id': '1571105055115583502',
#                         'lon': -87.82423,
#                         'name': 'Orange & Addison',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1571105055115583502',
#                         'station_type': 'lightweight'},
#                        {'address': '5448-5454, South Kildare Avenue, West '
#                                    'Elsdon, Archer Heights, Chicago, Lake '
#                                    'Township, Cook County, Illinois, 60629, '
#                                    'United States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1593766338948359064',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1593766338948359064',
#                         'has_kiosk': False,
#                         'lat': 41.793357,
#                         'legacy_id': '1593766338948359064',
#                         'lon': -87.730598,
#                         'name': 'Kildare Ave & 55th St',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1593766338948359064',
#                         'station_type': 'lightweight'},
#                        {'address': '3218-3220, North Lamon Avenue, Portage '
#                                    'Park, Chicago, Jefferson Township, Cook '
#                                    'County, Illinois, 60641, United States',
#                         'capacity': 9,
#                         'client_station_id': 'motivate_CHI_1563698701206292480',
#                         'dockless_bikes_parking_zone_capacity': 9,
#                         'eightd_has_key_dispenser': False,
#                         'eightd_station_services': [],
#                         'electric_bike_surcharge_waiver': False,
#                         'external_id': 'motivate_CHI_1563698701206292480',
#                         'has_kiosk': False,
#                         'lat': 41.9390108,
#                         'legacy_id': '1563698701206292480',
#                         'lon': -87.7492834,
#                         'name': 'Lamon Ave & Belmont Ave',
#                         'rack_model': 'CITY_PILOT_RACK',
#                         'region_code': 'CHI',
#                         'rental_uris': {'android': 'https://chi.lft.to/lastmile_qr_scan',
#                                         'ios': 'https://chi.lft.to/lastmile_qr_scan'},
#                         'station_id': '1563698701206292480',
#                         'station_type': 'lightweight'}]},
#  'last_updated': 1637201615,
#  'ttl': 5}

# %%
db_connection = psycopg2.connect(host='127.0.0.1',dbname="postgres", user="postgres" , password="root")

# %%
db_connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT) 

cursor = db_connection.cursor()

# %%
# uncomment the following line if you already created the database 
# Only once you need to create the database

cursor.execute("CREATE DATABASE chicago_divvy_stations_status;")
db_connection.commit()
# Out:
# ---------------------------------------------------------------------------
# DuplicateDatabase                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19088/226215880.py in <module>
#       2 # Only once you need to create the database
#       3
# ----> 4 cursor.execute("CREATE DATABASE chicago_divvy_stations_status;")
#       5 db_connection.commit()
#
# DuplicateDatabase: database "chicago_divvy_stations_status" already exists

# %%
db_connection = psycopg2.connect(host='127.0.0.1',dbname="chicago_divvy_stations_status", user="postgres" , password="root")

cursor = db_connection.cursor()

# %%
# Only once you need to create the postgis extension.
# Comment the following line if you already created the postgis extension

cursor.execute("CREATE EXTENSION postgis;")
# Out:
# ---------------------------------------------------------------------------
# DuplicateObject                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19088/2696227922.py in <module>
#       2 # Comment the following line if you already created the postgis extension
#       3
# ----> 4 cursor.execute("CREATE EXTENSION postgis;")
#
# DuplicateObject: extension "postgis" already exists

# %%
db_connection.commit()

# %%
cursor.execute("DROP TABLE IF EXISTS divvy_stations_realtime_status")

# %%
db_connection.commit()

# %%
cursor.execute("""CREATE TABLE divvy_stations_realtime_status(
                altitude FLOAT,
                availableBikes INTEGER,
                availableDocks INTEGER,
                city TEXT,
                id BIGINT,
                is_renting BOOLEAN,
                kioskType TEXT,
                landMark TEXT,
                lastCommunicationTime timestamp,
                latitude FLOAT,
                location TEXT,
                longitude FLOAT,
                postalCode INTEGER,
                stAddress1 TEXT,
                stAddress2 TEXT,
                stationName TEXT,
                status TEXT,
                statusKey INTEGER,
                statusValue TEXT,
                testStation BOOLEAN,
                totalDocks INTEGER,
                Where_IS GEOGRAPHY);""")

# %%
db_connection.commit()

# %% [markdown]
# ### The following is the Heartbeat Loop - Pulls data from divvy every 2 minutes in order to get realtime updates for the different divvy stations

# %%
while True:
    # Get divvy statations status
    # Status is returned as a json reply

    response_stations_info = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_information.json')

    response = urlopen('https://gbfs.divvybikes.com/gbfs/en/station_status.json')

    # Extract the body of the reply
    response_body = response.read()
    response_stations_info = response_stations_info.read()

    # Decode the format in json format
    stations_json = json.loads(response_body.decode("utf-8"))
    stations_info_json = json.loads(response_stations_info.decode("utf-8"))
    
    
    stations_dictionary = stations_json['data']
    stations_info_dictionary = stations_info_json['data']
    
    # load data file into a dataframe
    df__stations = pd.DataFrame(stations_dictionary['stations'])
    df__stations_info = pd.DataFrame(stations_info_dictionary['stations'])
    
    divvy_stations_realtime_status = pd.DataFrame(columns=[
                'altitude',
                'availableBikes',
                'availableDocks',
                'city',
                'id',
                'is_renting',
                'kioskType',
                'landMark',
                'lastCommunicationTime',
                'latitude',
                'location',
                'longitude',
                'postalCode',
                'stAddress1',
                'stAddress2',
                'stationName',
                'status',
                'statusKey',
                'statusValue',
                'testStation',
                'totalDocks' ])
    
    for x in range(len(df__stations.index)):
        has_kiosk = df__stations_info['has_kiosk'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0]
        row = [
            int(0),
            int(df__stations['num_bikes_available'].iloc[x]),
            int(df__stations['num_docks_available'].iloc[x]),
            'Chicago',
            int(df__stations['station_id'].iloc[x]),
            bool(df__stations['is_renting'].iloc[x]),
            has_kiosk,
            'Chicago',
            datetime.strptime(time.ctime(int(df__stations['last_reported'].iloc[x])), "%a %b %d %H:%M:%S %Y").strftime("%Y-%m-%d %H:%M:%S"),
            float(df__stations_info['lat'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0]),
            'Chicago',
            float(df__stations_info['lon'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0]),
            60602,
            'Chicago',
            'Chicago',
            df__stations_info['name'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0],
            'IN_SERVICE',
            1,
            'IN_SERVICE',
            False,
            int(df__stations_info['capacity'][df__stations_info['station_id'] == df__stations['station_id'].iloc[x] ].values[0])]
    
        divvy_stations_realtime_status.loc[len(divvy_stations_realtime_status)] = row

        
    divvy_stations_realtime_status['altitude'] = divvy_stations_realtime_status['altitude'].astype(float)
    divvy_stations_realtime_status['availableBikes'] = divvy_stations_realtime_status['availableBikes'].astype(int)
    divvy_stations_realtime_status['availableDocks'] = divvy_stations_realtime_status['availableDocks'].astype(int)
    divvy_stations_realtime_status['city'] = divvy_stations_realtime_status.city.astype(str)
    divvy_stations_realtime_status['id'] = divvy_stations_realtime_status['id'].astype('int64')
    divvy_stations_realtime_status['is_renting'] = divvy_stations_realtime_status['is_renting'].astype(bool)
    divvy_stations_realtime_status['kioskType'] = divvy_stations_realtime_status['kioskType'].astype(str)
    divvy_stations_realtime_status['landMark'] = divvy_stations_realtime_status['landMark'].astype(str)
    divvy_stations_realtime_status['lastCommunicationTime'] = divvy_stations_realtime_status['lastCommunicationTime'].astype(str)
    divvy_stations_realtime_status['latitude'] = divvy_stations_realtime_status['latitude'].astype(float)
    divvy_stations_realtime_status['location'] = divvy_stations_realtime_status['location'].astype(str)
    divvy_stations_realtime_status['longitude'] = divvy_stations_realtime_status['longitude'].astype(float)
    divvy_stations_realtime_status['postalCode'] = divvy_stations_realtime_status['postalCode'].astype(int)
    divvy_stations_realtime_status['stAddress1'] = divvy_stations_realtime_status['stAddress1'].astype(str)
    divvy_stations_realtime_status['stAddress2'] = divvy_stations_realtime_status['stAddress2'].astype(str)
    divvy_stations_realtime_status['stationName'] = divvy_stations_realtime_status['stationName'].astype(str)
    divvy_stations_realtime_status['status'] = divvy_stations_realtime_status['status'].astype(str)
    divvy_stations_realtime_status['statusKey'] = divvy_stations_realtime_status['statusKey'].astype(int)
    divvy_stations_realtime_status['statusValue'] = divvy_stations_realtime_status['statusValue'].astype(str)
    divvy_stations_realtime_status['testStation'] = divvy_stations_realtime_status['testStation'].astype(bool)
    divvy_stations_realtime_status['totalDocks'] = divvy_stations_realtime_status['totalDocks'].astype(int)
    
    # lets store our data subset into a file
    # This way you have a copy of data stored in a file 
    # that you could use in case you want to debug a problem on the orginal data received

    divvy_stations_realtime_status.to_csv('divvy_stations_status.csv',sep=',', encoding='utf-8', index=False)
    
    # delete existing data in the table
    cursor.execute("DELETE FROM divvy_stations_realtime_status")
    db_connection.commit()

    
    # Now we will connect to the database and store divvy data
    with open('divvy_stations_status.csv', 'r') as f:
        reader = csv.reader(f)
        next(reader)  # Skip the header row.
        for row in reader:
            cursor.execute( "INSERT INTO divvy_stations_realtime_status VALUES (%s, %s, %s, %s, %s,    %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,   %s, %s, %s, %s,%s,  %s, NULL)", row)

    
    
    db_connection.commit()
    
    cursor.execute("UPDATE divvy_stations_realtime_status SET Where_IS = ST_POINT(latitude,longitude);")
    db_connection.commit()
    
    
    # Now we will connect to ElasticSearch database and store divvy data
    divvy_stations_realtime_status = divvy_stations_realtime_status.to_json(orient='records')
    divvy_stations_realtime_status = json.loads(divvy_stations_realtime_status)
    load(es,divvy_stations_realtime_status)
    
    
    # Sleep for 3 minutes; divvy updates its stations status every 2 minutes
    now = datetime.now()
    timedate = ( (str(now.now())).split('.')[0]).split(' ')[0] + ' ' + ((str(now.now())).split('.')[0]).split(' ')[1]
 
    print(timedate, ' : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...')
    time.sleep(120)    
    continue
# Out:
# c:\users\nikhil\appdata\local\programs\python\python39\lib\site-packages\elasticsearch\connection\base.py:209: ElasticsearchWarning: Elasticsearch built-in security features are not enabled. Without authentication, your cluster could be accessible to anyone. See https://www.elastic.co/guide/en/elasticsearch/reference/7.15/security-minimal-setup.html to enable security.
#   warnings.warn(message, category=ElasticsearchWarning)
# c:\users\nikhil\appdata\local\programs\python\python39\lib\site-packages\elasticsearch\connection\base.py:209: ElasticsearchWarning: [types removal] Specifying types in bulk requests is deprecated.
#   warnings.warn(message, category=ElasticsearchWarning)
# 2021-11-17 20:14:44  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2021-11-17 20:17:07  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2021-11-17 20:19:29  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2021-11-17 20:21:51  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2021-11-17 20:24:14  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2021-11-17 20:26:26  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2021-11-17 20:28:39  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2021-11-17 20:30:52  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2021-11-17 20:33:05  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...
# 2021-11-17 20:35:17  : Sent Heartbeat to Divvy Servers and Going to sleep for 2 minutes now ...

# %%
# close connection at the end of the script

db_connection.close()
